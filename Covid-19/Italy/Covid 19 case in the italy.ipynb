# %%
# Covid 19

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("italy_total.csv")

# %%
data.head()
# Out:
#          date  hospitalized_with_symptoms  intensive_care  total_hospitalized  \
# 0  2020-02-24                         101              26                 127
# 1  2020-02-25                         114              35                 150
# 2  2020-02-26                         128              36                 164
# 3  2020-02-27                         248              56                 304
# 4  2020-02-28                         345              64                 409
#
#    home_confinement  cumulative_positive_cases  daily_positive_cases  \
# 0                94                        221                     0
# 1               162                        311                    90
# 2               221                        385                    74
# 3               284                        588                   203
# 4               412                        821                   233
#
#    recovered  death  positive_clinical_activity  positive_surveys_tests  \
# ...

# %%
data2=pd.read_csv("covid19_italy_region.csv")

# %%
data2.head()
# Out:
#    SNo                 Date Country  RegionCode      RegionName   Latitude  \
# 0    0  2020-02-24T18:00:00     ITA          13         Abruzzo  42.351222
# 1    1  2020-02-24T18:00:00     ITA          17      Basilicata  40.639471
# 2    2  2020-02-24T18:00:00     ITA          18        Calabria  38.905976
# 3    3  2020-02-24T18:00:00     ITA          15        Campania  40.839566
# 4    4  2020-02-24T18:00:00     ITA           8  Emilia-Romagna  44.494367
#
#    Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0  13.398438                     0                      0
# 1  15.805148                     0                      0
# 2  16.594402                     0                      0
# 3  14.250850                     0                      0
# 4  11.341721                    10                      2
#
#    TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# 0                          0                0                     0
# ...

# %%
data.shape
# Out:
# (1131, 19)

# %%
data2.shape
# Out:
# (6027, 17)

# %%
data.columns
# Out:
# Index(['date', 'hospitalized_with_symptoms', 'intensive_care',
#        'total_hospitalized', 'home_confinement', 'cumulative_positive_cases',
#        'daily_positive_cases', 'recovered', 'death',
#        'positive_clinical_activity', 'positive_surveys_tests',
#        'cumulative_cases', 'total_tests', 'total_people_tested',
#        'new_intensive_care', 'total_positive_molecular_test',
#        'total_positive_rapid_antigen_test', 'molecular_test',
#        'rapid_antigen_test'],
#       dtype='object')

# %%
data.tail()
# Out:
#             date  hospitalized_with_symptoms  intensive_care  \
# 1126  2023-03-26                        2516             102
# 1127  2023-03-27                        2526              95
# 1128  2023-03-28                        2548              99
# 1129  2023-03-29                        2556              96
# 1130  2023-03-30                        2533              84
#
#       total_hospitalized  home_confinement  cumulative_positive_cases  \
# 1126                2618            135655                     138273
# 1127                2621            133236                     135857
# 1128                2647            131923                     134570
# 1129                2652            130662                     133314
# 1130                2617            131051                     133668
#
#       daily_positive_cases  recovered   death  positive_clinical_activity  \
# 1126                  -793   25354960  188983                         NaN
# ...

# %%
data.describe()
# Out:
#        hospitalized_with_symptoms  intensive_care  total_hospitalized  \
# count                 1131.000000     1131.000000         1131.000000
# mean                  9960.704686      966.588859        10927.294430
# std                   8615.462600     1095.122565         9663.472247
# min                    101.000000       26.000000          127.000000
# 25%                   3419.000000      226.500000         3644.500000
# 50%                   7019.000000      409.000000         7328.000000
# 75%                  15054.000000     1489.000000        16568.500000
# max                  34697.000000     4068.000000        38507.000000
#
#        home_confinement  cumulative_positive_cases  daily_positive_cases  \
# count      1.131000e+03               1.131000e+03           1131.000000
# mean       4.635780e+05               4.745053e+05            117.990274
# std        5.114059e+05               5.145508e+05          20599.134875
# ...

# %%
data.isnull().sum()
# Out:
# date                                   0
# hospitalized_with_symptoms             0
# intensive_care                         0
# total_hospitalized                     0
# home_confinement                       0
# cumulative_positive_cases              0
# daily_positive_cases                   0
# recovered                              0
# death                                  0
# positive_clinical_activity           969
# positive_surveys_tests               969
# cumulative_cases                       0
# total_tests                            0
# total_people_tested                   55
# new_intensive_care                   283
# total_positive_molecular_test        326
# total_positive_rapid_antigen_test    326
# molecular_test                       326
# rapid_antigen_test                   326
# dtype: int64

# %%
data3=data.drop(['new_intensive_care','total_positive_molecular_test','total_positive_rapid_antigen_test','molecular_test','positive_clinical_activity','positive_surveys_tests'],axis=1)

# %%
data3.head()
# Out:
#          date  hospitalized_with_symptoms  intensive_care  total_hospitalized  \
# 0  2020-02-24                         101              26                 127
# 1  2020-02-25                         114              35                 150
# 2  2020-02-26                         128              36                 164
# 3  2020-02-27                         248              56                 304
# 4  2020-02-28                         345              64                 409
#
#    home_confinement  cumulative_positive_cases  daily_positive_cases  \
# 0                94                        221                     0
# 1               162                        311                    90
# 2               221                        385                    74
# 3               284                        588                   203
# 4               412                        821                   233
#
#    recovered  death  cumulative_cases  total_tests  total_people_tested  \
# ...

# %%
data3.isnull().sum()
# Out:
# date                            0
# hospitalized_with_symptoms      0
# intensive_care                  0
# total_hospitalized              0
# home_confinement                0
# cumulative_positive_cases       0
# daily_positive_cases            0
# recovered                       0
# death                           0
# cumulative_cases                0
# total_tests                     0
# total_people_tested            55
# rapid_antigen_test            326
# dtype: int64

# %%
data3.shape
# Out:
# (1131, 13)

# %% [markdown]
# # Relating the variable with Scatterplots

# %%
sns.relplot(x='total_tests',y='total_hospitalized',data=data3)

# %%
sns.relplot(x='total_tests',y='recovered',data=data3)

# %%
sns.relplot(x='cumulative_positive_cases',y='recovered',data=data3)

# %%
data3.describe()
# Out:
#        hospitalized_with_symptoms  intensive_care  total_hospitalized  \
# count                 1131.000000     1131.000000         1131.000000
# mean                  9960.704686      966.588859        10927.294430
# std                   8615.462600     1095.122565         9663.472247
# min                    101.000000       26.000000          127.000000
# 25%                   3419.000000      226.500000         3644.500000
# 50%                   7019.000000      409.000000         7328.000000
# 75%                  15054.000000     1489.000000        16568.500000
# max                  34697.000000     4068.000000        38507.000000
#
#        home_confinement  cumulative_positive_cases  daily_positive_cases  \
# count      1.131000e+03               1.131000e+03           1131.000000
# mean       4.635780e+05               4.745053e+05            117.990274
# std        5.114059e+05               5.145508e+05          20599.134875
# ...

# %%
sns.relplot(x='intensive_care',hue='intensive_care',y='total_hospitalized',data=data3)

# %%
data3.isnull().sum()
# Out:
# date                            0
# hospitalized_with_symptoms      0
# intensive_care                  0
# total_hospitalized              0
# home_confinement                0
# cumulative_positive_cases       0
# daily_positive_cases            0
# recovered                       0
# death                           0
# cumulative_cases                0
# total_tests                     0
# total_people_tested            55
# rapid_antigen_test            326
# dtype: int64

# %%
sns.relplot(x='total_people_tested',y='rapid_antigen_test',data=data3)

# %%
sns.relplot(y='total_people_tested',x='rapid_antigen_test',data=data3)

# %%
data3.columns
# Out:
# Index(['date', 'hospitalized_with_symptoms', 'intensive_care',
#        'total_hospitalized', 'home_confinement', 'cumulative_positive_cases',
#        'daily_positive_cases', 'recovered', 'death', 'cumulative_cases',
#        'total_tests', 'total_people_tested', 'rapid_antigen_test'],
#       dtype='object')

# %%
sns.relplot(x='date',y='recovered',data=data3)

# %%
sns.barplot(y='hospitalized_with_symptoms',x='total_hospitalized',data=data3)
# Out:
# <AxesSubplot:xlabel='total_hospitalized', ylabel='hospitalized_with_symptoms'>

# %%
sns.relplot(y='hospitalized_with_symptoms',hue='recovered',x='total_hospitalized',data=data3)

# %%
sns.pairplot(data3)

# %%
sns.relplot(x='rapid_antigen_test',y='death',kind='line',data=data3)

# %%
sns.relplot(x='rapid_antigen_test',y='home_confinement',kind='line',data=data3)

# %%
data.columns
# Out:
# Index(['date', 'hospitalized_with_symptoms', 'intensive_care',
#        'total_hospitalized', 'home_confinement', 'cumulative_positive_cases',
#        'daily_positive_cases', 'recovered', 'death',
#        'positive_clinical_activity', 'positive_surveys_tests',
#        'cumulative_cases', 'total_tests', 'total_people_tested',
#        'new_intensive_care', 'total_positive_molecular_test',
#        'total_positive_rapid_antigen_test', 'molecular_test',
#        'rapid_antigen_test'],
#       dtype='object')

# %%
sns.catplot(x='date',y='daily_positive_cases',data=data3)

# %%
sns.catplot(x='intensive_care',y='hospitalized_with_symptoms',data=data3)
